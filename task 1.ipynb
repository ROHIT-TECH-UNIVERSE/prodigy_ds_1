# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
titanic_train=pd.read_csv('train.csv')
titanic_test=pd.read_csv('test.csv')

# %%
sex=titanic_train.Sex
sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
plt.figure(figsize=(5,5))
plt.hist(sex,bins=3,ec="black")
plt.xlabel("gender")
plt.ylabel("count")
plt.title("the gender graph ",fontsize=16)
plt.grid(color="red",axis='y')

plt.show()

# %%
data=pd.DataFrame(titanic_train)

# %%
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7984\3903555505.py in <module>
# ----> 1 fig
#
# NameError: name 'fig' is not defined

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,2,1])
x=list(data.iloc[:0])
y=list(data.iloc[:1])
ax.bar(x,y,color='b')
plt.show()

# %%
# for age distribution histogram from the famous titanic data set
# making a series of the data from the specific dat set so that we can plot a histogram
age=titanic_train.Age
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# the below statement is to give the axis space i.e dist between two point on a axis
# syn=plt.figure(figsize=(x,y))
plt.figure(figsize=(10,10))

# the below is for ploting the histohgram 
plt.hist(age,bins=8,facecolor="gray",ec="black")

# to align the histogram to the margin so as to have a proper view
plt.margins(x=0)

# labels for the axis and title
plt.xlabel("age")
plt.ylabel("count")
plt.title("The Age Differee ",fontsize=16)
plt.grid(color="grey",axis='y')

plt.show()
